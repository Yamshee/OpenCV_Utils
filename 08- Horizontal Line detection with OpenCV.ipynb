# %%
import cv2
import math
from PIL import Image 
from IPython.display import display

img = cv2.imread(r'/mnt/c/Users/yamshee.fatima/Desktop/image & OCR/parking.png')
img
# Out:
# array([[[154, 161, 164],
#         [153, 161, 164],
#         [150, 159, 161],
#         ...,
#         [156, 162, 166],
#         [154, 160, 162],
#         [149, 160, 161]],
#
#        [[155, 165, 165],
#         [148, 155, 156],
#         [148, 157, 156],
#         ...,
#         [151, 160, 159],
#         [152, 159, 158],
#         [152, 158, 160]],
#
#        [[157, 165, 166],
#         [152, 163, 165],
#         [151, 162, 164],
#         ...,
#         [148, 157, 161],
#         [147, 157, 160],
#         [150, 159, 160]],
#
#        ...,
#        [[149, 156, 155],
#         [152, 160, 160],
#         [148, 157, 159],
#         ...,
#         [153, 161, 162],
#         [155, 163, 165],
#         [152, 156, 158]],
#
#        [[149, 158, 156],
#         [152, 161, 160],
#         [151, 161, 163],
#         ...,
#         [155, 165, 167],
#         [159, 169, 172],
#         [153, 161, 164]],
#
#        [[149, 161, 157],
#         [151, 162, 161],
#         [152, 163, 165],
#         ...,
#         [151, 160, 162],
#         [154, 161, 163],
#         [150, 155, 157]]], dtype=uint8)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 80, 120)
lines = cv2.HoughLinesP(edges, 1, math.pi/2, 2, None, 30, 1);
for line in lines[0]:
    pt1 = (line[0],line[1])
    pt2 = (line[2],line[3])
    cv2.line(img, pt1, pt2, (0,0,255), 3)

# %%
display(Image.fromarray(img))

#cv2.imwrite("C:/temp/2.png", img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FC7938EC0B8>
